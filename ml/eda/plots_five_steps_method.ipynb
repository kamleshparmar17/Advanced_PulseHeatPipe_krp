# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns
import numpy as np

# %%
df =  pd.read_excel("../../data/observation_alpha_beta.xlsx")

# %%
df.head()
# Out:
#    Q[W]  alpha  beta  Te1[K]  Te2[K]  dTe[K]  Tc1[K]  Tc2[K]  dTc[K]  \
# 0    40     90     0     348   352.0     4.0   306.0   315.0     9.0
# 1    40     60     0     349   357.0     8.0   304.0   305.0     1.0
# 2    40     30     0     349   358.5     9.5   304.0   306.0     2.0
# 3    60     60     0     350   355.0     5.0   303.0   319.0    16.0
# 4    60     30     0     350   359.0     9.0   305.0   321.0    16.0
#
#    TR1[K/W]  Change_in_TR1  Change_in_TR1[%]  TR2[K/W]  Change_in_TR2  \
# 0  1.050000       0.000000          0.000000  0.925000       0.000000
# 1  1.125000      -0.071429         -7.142857  1.300000      -0.405405
# 2  1.125000      -0.071429         -7.142857  1.312500      -0.418919
# 3  0.783333            NaN               NaN  0.633333            NaN
# 4  0.750000            NaN               NaN  0.437500            NaN
#
#    Change_in_TR2[%]  P1[bar]  P2[bar]  dG1[KJ/mol]  dGmin[KJ/mol]  dG2[KJ/mol]
# 0          0.000000     0.62     0.75         -155           -190      -100.00
# 1        -40.540541     0.70     0.80         -140           -160        -0.85
# 2        -41.891892     0.70     0.83         -130           -150       -90.00
# 3               NaN     0.65     1.00         -160           -180         0.00
# 4               NaN     0.75     1.00         -120           -150         0.00

# %%
df.fillna(0,inplace=True)

# %%
df_1=df[df['beta']==0]

# %%
display(df_1)
# Out:
#     Q[W]  alpha  beta  Te1[K]  Te2[K]  dTe[K]  Tc1[K]  Tc2[K]  dTc[K]  \
# 0     40     90     0     348   352.0     4.0   306.0   315.0     9.0
# 1     40     60     0     349   357.0     8.0   304.0   305.0     1.0
# 2     40     30     0     349   358.5     9.5   304.0   306.0     2.0
# 3     60     60     0     350   355.0     5.0   303.0   319.0    16.0
# 4     60     30     0     350   359.0     9.0   305.0   321.0    16.0
# 5     80     90     0     350   355.0     5.0   302.0   320.0    18.0
# 6     80     60     0     355   358.0     3.0   305.0   313.0     8.0
# 7     80     30     0     348   358.0    10.0   303.0   322.0    19.0
# 8     80      0     0     360   364.0     4.0   303.0   303.5     0.5
# 9    100     90     0     352   355.0     3.0   305.0   315.0    10.0
# 10   100     60     0     353   358.0     5.0   306.0   321.0    15.0
# 11   100     30     0     346   357.0    11.0   306.0   325.0    19.0
# 12   100      0     0     350   385.0    35.0   302.0   306.0     4.0
# 13   120     90     0     353   356.0     3.0   304.0   315.0    11.0
# 14   120     60     0     353   356.0     3.0   307.0   313.0     6.0
# 15   120     30     0     348   358.0    10.0   303.0   323.0    20.0
#
#     TR1[K/W]  Change_in_TR1  Change_in_TR1[%]  TR2[K/W]  Change_in_TR2  \
# 0   1.050000       0.000000          0.000000  0.925000       0.000000
# 1   1.125000      -0.071429         -7.142857  1.300000      -0.405405
# 2   1.125000      -0.071429         -7.142857  1.312500      -0.418919
# 3   0.783333       0.000000          0.000000  0.633333       0.000000
# 4   0.750000       0.000000          0.000000  0.437500       0.000000
# 5   0.600000       0.000000          0.000000  0.562500       0.000000
# 6   0.625000      -0.041667         -4.166667  0.450000       0.200000
# 7   0.562500       0.062500          6.250000  0.756250      -0.344444
# 8   0.712500      -0.187500        -18.750000  0.400000       0.288889
# 9   0.470000       0.000000          0.000000  0.370000       0.000000
# 10  0.470000       0.000000          0.000000  0.320000       0.135135
# 11  0.400000       0.148936         14.893617  0.790000      -1.135135
# 12  0.480000      -0.021277         -2.127660  0.341667       0.076577
# 13  0.408333       0.000000          0.000000  0.358333       0.000000
# 14  0.383333       0.061224          6.122449  0.291667       0.186047
# 15  0.375000       0.081633          8.163265  1.237500      -2.453488
#
#     Change_in_TR2[%]  P1[bar]  P2[bar]  dG1[KJ/mol]  dGmin[KJ/mol]  \
# 0           0.000000     0.62     0.75         -155           -190
# 1         -40.540541     0.70     0.80         -140           -160
# 2         -41.891892     0.70     0.83         -130           -150
# 3           0.000000     0.65     1.00         -160           -180
# 4           0.000000     0.75     1.00         -120           -150
# 5           0.000000     0.75     1.00         -125           -150
# 6          20.000000     0.80     1.00          -85           -100
# 7         -34.444444     0.65     1.00         -160           -200
# 8          28.888889     0.70     0.75         -150           -160
# 9           0.000000     0.72     1.00         -130           -160
# 10         13.513514     0.75     1.00         -120           -130
# 11       -113.513514     0.45     1.00         -250           -280
# 12          7.657658     0.67     0.69         -270           -370
# 13          0.000000     0.77     1.00         -100           -130
# 14         18.604651     0.80     1.00          -75            -85
# 15       -245.348837     0.60     1.00         -185           -230
#
#     dG2[KJ/mol]
# 0       -100.00
# 1         -0.85
# 2        -90.00
# 3          0.00
# 4          0.00
# 5          0.00
# 6          0.00
# 7          0.00
# 8       -140.00
# 9          0.00
# 10         0.00
# 11         0.00
# 12      -240.00
# 13         0.00
# 14         0.00
# 15         0.00

# %%
plt.figure(figsize=(8, 6))

sns.lineplot(
    data=df_1,
    x="alpha",
    y="Change_in_TR1[%]",
    hue="Q[W]"   
        
)

# Add title and labels
plt.title("Change in Thermal Resistance1 (TR1) [%] vs Alpha [°]", fontsize=14, fontweight='bold')
plt.xlabel("Alpha [°]", fontsize=12)
plt.ylabel("Change in Thermal Resistance1 (TR1) [%]", fontsize=12)

# Customize y-axis ticks to include values from (-25) to (40) at every 5
plt.yticks(np.arange(-20, 20, 5))
# Out:
# ([<matplotlib.axis.YTick at 0x1dd9cda5ed0>,
#   <matplotlib.axis.YTick at 0x1dd9b77da10>,
#   <matplotlib.axis.YTick at 0x1dda0315650>,
#   <matplotlib.axis.YTick at 0x1dda02ea410>,
#   <matplotlib.axis.YTick at 0x1dda0302d50>,
#   <matplotlib.axis.YTick at 0x1dda0302c10>,
#   <matplotlib.axis.YTick at 0x1dda03012d0>,
#   <matplotlib.axis.YTick at 0x1dd9caca550>],
#  [Text(0, -20, '−20'),
#   Text(0, -15, '−15'),
#   Text(0, -10, '−10'),
#   Text(0, -5, '−5'),
#   Text(0, 0, '0'),
#   Text(0, 5, '5'),
#   Text(0, 10, '10'),
#   Text(0, 15, '15')])

# %%
display(df)
# Out:
#     Q[W]  alpha  beta  Te1[K]  Te2[K]  dTe[K]  Tc1[K]  Tc2[K]  dTc[K]  \
# 0     40     90     0     348   352.0     4.0   306.0   315.0     9.0
# 1     40     60     0     349   357.0     8.0   304.0   305.0     1.0
# 2     40     30     0     349   358.5     9.5   304.0   306.0     2.0
# 3     60     60     0     350   355.0     5.0   303.0   319.0    16.0
# 4     60     30     0     350   359.0     9.0   305.0   321.0    16.0
# 5     80     90     0     350   355.0     5.0   302.0   320.0    18.0
# 6     80     60     0     355   358.0     3.0   305.0   313.0     8.0
# 7     80     30     0     348   358.0    10.0   303.0   322.0    19.0
# 27  0.416667      -0.020408         -2.040816  0.466667      -0.302326
# 28  0.333333       0.183673         18.367347  0.208333       0.418605
# 29  0.325000       0.204082         20.408163  0.233333       0.348837
#
#     Change_in_TR2[%]  P1[bar]  P2[bar]  dG1[KJ/mol]  dGmin[KJ/mol]  \
# 0           0.000000     0.62     0.75         -155           -190
# 1         -40.540541     0.70     0.80         -140           -160
# 2         -41.891892     0.70     0.83         -130           -150
# 3           0.000000     0.65     1.00         -160           -180
# 4           0.000000     0.75     1.00         -120           -150
# 5           0.000000     0.75     1.00         -125           -150
# 6          20.000000     0.80     1.00          -85           -100
# 7         -34.444444     0.65     1.00         -160           -200
# 8          28.888889     0.70     0.75         -150           -160
# 9           0.000000     0.72     1.00         -130           -160
# 10         13.513514     0.75     1.00         -120           -130
# 11       -113.513514     0.45     1.00         -250           -280
# 12          7.657658     0.67     0.69         -270           -370
# 13          0.000000     0.77     1.00         -100           -130
# 14         18.604651     0.80     1.00          -75            -85
# 15       -245.348837     0.60     1.00         -185           -230
# 16        -33.783784     0.50     0.58         -220           -235
# 17        -21.621622     0.60     0.72         -175           -190
# 18        -29.729730     0.55     0.60         -230           -240
# 19          0.000000     0.62     0.80         -155           -175
# 20          0.000000     0.50     0.74         -220           -225
# 21          0.000000     0.68     0.78         -130           -260
# 22         31.111111     0.62     1.00         -160           -230
# 23         37.777778     0.46     0.92         -255           -300
# 24        -78.378378     0.55     1.00         -150           -170
# 25         27.027027     0.48     1.00         -220           -250
# 26         29.729730     0.60     1.00         -150           -210
# 27        -30.232558     0.60     1.00          215           -230
# 28         41.860465     0.54     1.00         -215           -230
# 29         34.883721     0.52     1.00         -200           -250
#
#     dG2[KJ/mol]
# 0       -100.00
# 1         -0.85
# 2        -90.00
# 3          0.00
# 4          0.00
# 5          0.00
# 6          0.00
# 7          0.00
# 8       -140.00
# 9          0.00
# 10         0.00
# 11         0.00
# 12      -240.00
# 13         0.00
# 14         0.00
# 15         0.00
# 16      -225.00
# 17      -120.00
# 18      -220.00
# 19       -90.00
# 20       -75.00
# 21       -70.00
# 22         0.00
# 23       -20.00
# 24         0.00
# 25         0.00
# 26         0.00
# 27         0.00
# 28         0.00
# 29         0.00

# %% [markdown]
# # Various Alpha and constant Beta (0°)

# %%
# Set style and context for publication-quality visuals
sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

# Define a color palette for clear differentiation
palette = sns.color_palette("tab10")  # Use a vivid palette for clarity

# Create the plot
plt.figure(figsize=(8, 6))

# Plot the data with enhancements
sns.lineplot(
    data=df,
    x="alpha",
    y="TR1[K/W]",
    hue="Q[W]",
    style="Q[W]",  # Different line styles based on "Q[W]"
    markers=True,  # Add markers for data points
    dashes=False,  # Use solid lines
    palette=palette,  # Use the vivid color palette
    marker='o',  # Circular markers
    markerfacecolor='auto',  # Markers filled with line color
    markeredgecolor='black',  # Black edge for better contrast
    markeredgewidth=1  # Adjust the edge width
)

# Add title and labels
plt.title("Thermal Resistance1 (TR1) vs Alpha", fontsize=14, fontweight='bold')
plt.xlabel("Alpha [°]", fontsize=12)
plt.ylabel("Thermal Resistance1 (TR1) [K/W]", fontsize=12)

# Customize y-axis ticks to include values from 0.2 to 1.2 at every 0.2
plt.yticks(np.arange(0, 1.4, 0.2))

# Customize legend
plt.legend(
    title="Heat Input [Q(W)]",
    fontsize=10,
    title_fontsize=12,
    loc="upper left",  # Place the legend at the upper-right corner
    frameon=True,  # Add a box around the legend
    shadow=False   # Avoid shadow for a cleaner look
)

# Add grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.6, alpha=0.8)

# Display the plot
#plt.tight_layout()
plt.show()
# Out:
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_1000\72761025.py:12: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   sns.lineplot(

# %%
# Set style and context for publication-quality visuals
sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

# Define a color palette for clear differentiation
palette = sns.color_palette("tab10")  # Use a vivid palette for clarity

# Create the plot
plt.figure(figsize=(8, 6))

# Plot the data with enhancements
sns.lineplot(
    data=df,
    x="alpha",
    y="TR2[K/W]",
    hue="Q[W]",
    style="Q[W]",  # Different line styles based on "Q[W]"
    markers=True,  # Add markers for data points
    dashes=False,  # Use solid lines
    palette=palette,  # Use the vivid color palette
    marker='o',  # Circular markers
    markerfacecolor='auto',  # Markers filled with line color
    markeredgecolor='black',  # Black edge for better contrast
    markeredgewidth=1  # Adjust the edge width
)

# Add title and labels
plt.title("Thermal Resistance2 (TR2) vs Alpha", fontsize=14, fontweight='bold')
plt.xlabel("Alpha [°]", fontsize=12)
plt.ylabel("Thermal Resistance2 (TR2) [K/W]", fontsize=12)

# Customize y-axis ticks to include values from 0.2 to 1.2 at every 0.2
plt.yticks(np.arange(0, 1.4, 0.2))

# Customize legend
plt.legend(
    title="Heat Input [Q(W)]",
    fontsize=10,
    title_fontsize=12,
    loc="upper left",  # Place the legend at the upper-right corner
    frameon=True,  # Add a box around the legend
    shadow=False   # Avoid shadow for a cleaner look
)

# Add grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.6, alpha=0.8)

# Display the plot
#plt.tight_layout()
plt.show()
# Out:
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_1000\366304141.py:12: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   sns.lineplot(

# %%
# Filter the data for alpha only (example: alpha == 90)
alpha_only_data = df[df["alpha"] == 90]  # Adjust the filter as needed

# Plot the graph
plt.figure(figsize=(8, 6))
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="Te1[K]",
    marker="o",
    label="Te1[K]",
    linewidth=1,
    color='blue'
)
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="Te2[K]",
    marker="o",
    label="Te2[K]",
    linewidth=1,
    color='red',
    ci=None  # Remove standard deviation shadow
)
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="Tc1[K]",
    marker="o",
    label="Tc1[K]",
    linewidth=1,
    color='green',
    ci=None  # Remove standard deviation shadow
)
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="Tc2[K]",
    marker="o",
    label="Tc2[K]",
    linewidth=1,
    color='orange',
    ci=None  # Remove standard deviation shadow
)

# Enhance the graph for publication
plt.title("Temperature vs Heat Input at Alpha 90° and Beta 0°", fontsize=14)
plt.xlabel("Heat Input Q [W]", fontsize=12)
plt.ylabel("Temperature [K]", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=10, title="Temperature Metrics")
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_1000\2907353468.py:15: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_1000\2907353468.py:25: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_1000\2907353468.py:35: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(

# %%
# Filter the data for alpha only (example: alpha == 60)
alpha_only_data = df[df["alpha"] == 60]  # Adjust the filter as needed

# Plot the graph
plt.figure(figsize=(8, 6))
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="Te1[K]",
    marker="o",
    label="Te1[K]",
    linewidth=1,
    color='blue'
)
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="Te2[K]",
    marker="o",
    label="Te2[K]",
    linewidth=1,
    color='red'
)
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="Tc1[K]",
    marker="o",
    label="Tc1[K]",
    linewidth=1,
    color='green'
)
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="Tc2[K]",
    marker="o",
    label="Tc2[K]",
    linewidth=1,
    color='orange'
)

# Enhance the graph for publication
plt.title("Temperature vs Heat Input at Alpha 60° and Beta 0°", fontsize=14)
plt.xlabel("Heat Input Q [W]", fontsize=12)
plt.ylabel("Temperature [K]", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=10, title="Temperature Metrics")
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Filter the data for alpha only (example: alpha == 30)
alpha_only_data = df[df["alpha"] == 30]  # Adjust the filter as needed

# Plot the graph
plt.figure(figsize=(8, 6))
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="Te1[K]",
    marker="o",
    label="Te1[K]",
    linewidth=1,
    color='blue'
)
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="Te2[K]",
    marker="o",
    label="Te2[K]",
    linewidth=1,
    color='red'
)
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="Tc1[K]",
    marker="o",
    label="Tc1[K]",
    linewidth=1,
    color='green'
)
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="Tc2[K]",
    marker="o",
    label="Tc2[K]",
    linewidth=1,
    color='orange'
)

# Enhance the graph for publication
plt.title("Temperature vs Heat Input at Alpha 30° and Beta 0°", fontsize=14)
plt.xlabel("Heat Input Q [W]", fontsize=12)
plt.ylabel("Temperature [K]", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=10, title="Temperature Metrics")
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Filter the data for alpha only (example: alpha == 90)
alpha_only_data = df[df["alpha"] == 90]  # Adjust the filter as needed

# Plot the graph
plt.figure(figsize=(8, 6))
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="dTe[K]",
    marker="o",
    label=r"$dT_e[K]$",
    linewidth=2,
    color='blue',
    ci=None  # Remove standard deviation shadow
)
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="dTc[K]",
    marker="o",
    label=r"$dT_c[K]$",
    linewidth=2,
    color='red',
    ci=None  # Remove standard deviation shadow
)

# Enhance the graph for publication
plt.title(r"Temperature Difference $dT[K]$ vs Heat Input $Q[W]$ at Alpha 90° and Beta 0°", fontsize=14)
plt.xlabel("Heat Input Q [W]", fontsize=12)
plt.ylabel("Temperature Difference dT [K]", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=10, title="Temperature Differences")
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_1000\3547823661.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_1000\3547823661.py:16: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(

# %%
# Filter the data for alpha only (example: alpha == 60)
alpha_only_data = df[df["alpha"] == 60]  # Adjust the filter as needed

# Plot the graph
plt.figure(figsize=(8, 6))
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="dTe[K]",
    marker="o",
    label=r"$dT_e[K]$",
    linewidth=2,
    color='blue'
)
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="dTc[K]",
    marker="o",
    label=r"$dT_c[K]$",
    linewidth=2,
    color='red'
)

# Enhance the graph for publication
plt.title(r"Temperature Difference $dT[K]$ vs Heat Input $Q[W]$ at Alpha 60° and Beta 0°", fontsize=14)
plt.xlabel("Heat Input Q [W]", fontsize=12)
plt.ylabel("Temperature Difference dT [K]", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=10, title="Temperature Differences")
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Filter the data for alpha only (example: alpha == 30)
alpha_only_data = df[df["alpha"] == 30]  # Adjust the filter as needed

# Plot the graph
plt.figure(figsize=(8, 6))
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="dTe[K]",
    marker="o",
    label=r"$dT_e[K]$",
    linewidth=2,
    color='blue'
)
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="dTc[K]",
    marker="o",
    label=r"$dT_c[K]$",
    linewidth=2,
    color='red'
)

# Enhance the graph for publication
plt.title(r"Temperature Difference $dT[K]$ vs Heat Input $Q[W]$ at Alpha 30° and Beta 0°", fontsize=14)
plt.xlabel("Heat Input Q [W]", fontsize=12)
plt.ylabel("Temperature Difference dT [K]", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=10, title="Temperature Differences")
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # Constant Alpha (90°) and various Beta

# %%
# Set style and context for publication-quality visuals
sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

# Define a color palette for clear differentiation
palette = sns.color_palette("tab10")  # Use a vivid palette for clarity

# Create the plot
plt.figure(figsize=(8, 6))

# Plot the data with enhancements
sns.lineplot(
    data=df,
    x="beta",
    y="TR1[K/W]",
    hue="Q[W]",
    style="Q[W]",  # Different line styles based on "Q[W]"
    markers=True,  # Add markers for data points
    dashes=False,  # Use solid lines
    palette=palette,  # Use the vivid color palette
    marker='o',  # Circular markers
    markerfacecolor='auto',  # Markers filled with line color
    markeredgecolor='black',  # Black edge for better contrast
    markeredgewidth=1  # Adjust the edge width
)

# Add title and labels
plt.title("Thermal Resistance (TR1) vs Beta", fontsize=14, fontweight='bold')
plt.xlabel("Beta [°]", fontsize=12)
plt.ylabel("Thermal Resistance (TR1) [K/W]", fontsize=12)

# Customize y-axis ticks to include values from 0.2 to 1.2 at every 0.2
plt.yticks(np.arange(0, 1.4, 0.2))

# Customize legend
plt.legend(
    title="Heat Input [Q(W)]",
    fontsize=10,
    title_fontsize=12,
    loc="lower right",  # Place the legend at the upper-right corner
    frameon=True,  # Add a box around the legend
    shadow=False   # Avoid shadow for a cleaner look
)

# Add grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.6, alpha=0.8)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_1000\2426747248.py:12: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   sns.lineplot(

# %%
# Set style and context for publication-quality visuals
sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

# Define a color palette for clear differentiation
palette = sns.color_palette("tab10")  # Use a vivid palette for clarity

# Create the plot
plt.figure(figsize=(8, 6))

# Plot the data with enhancements
sns.lineplot(
    data=df,
    x="beta",
    y="TR2[K/W]",
    hue="Q[W]",
    style="Q[W]",  # Different line styles based on "Q[W]"
    markers=True,  # Add markers for data points
    dashes=False,  # Use solid lines
    palette=palette,  # Use the vivid color palette
    marker='o',  # Circular markers
    markerfacecolor='auto',  # Markers filled with line color
    markeredgecolor='black',  # Black edge for better contrast
    markeredgewidth=1  # Adjust the edge width
)

# Add title and labels
plt.title("Thermal Resistance (TR2) vs Beta", fontsize=14, fontweight='bold')
plt.xlabel("Beta [°]", fontsize=12)
plt.ylabel("Thermal Resistance (TR2) [K/W]", fontsize=12)

# Customize y-axis ticks to include values from 0.2 to 1.2 at every 0.2
plt.yticks(np.arange(0, 1.4, 0.2))

# Customize legend
plt.legend(
    title="Heat Input [Q(W)]",
    fontsize=10,
    title_fontsize=12,
    loc="lower right",  # Place the legend at the upper-right corner
    frameon=True,  # Add a box around the legend
    shadow=False   # Avoid shadow for a cleaner look
)

# Add grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.6, alpha=0.8)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_1000\652969093.py:12: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   sns.lineplot(

# %%
# Filter the data for beta only (example: beta == 90)
beta_only_data = df[df["beta"] == 90]  # Adjust the filter as needed

# Plot the graph
plt.figure(figsize=(8, 6))
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Te1[K]",
    marker="o",
    label="Te1[K]",
    linewidth=1.5,
    color='blue'
)
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Te2[K]",
    marker="o",
    label="Te2[K]",
    linewidth=1.5,
    color='red'
)
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Tc1[K]",
    marker="o",
    label="Tc1[K]",
    linewidth=1.5,
    color='green'
)
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Tc2[K]",
    marker="o",
    label="Tc2[K]",
    linewidth=1.5,
    color='orange'
)

# Enhance the graph for publication
plt.title("Temperature vs Heat Input at Alpha 90° and Beta 90°", fontsize=14)
plt.xlabel("Heat Input Q [W]", fontsize=12)
plt.ylabel("Temperature [K]", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)  # Use `alpha` for transparency
plt.legend(fontsize=10, title="Temperature Metrics")
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Filter the data for beta only (example: beta == 90)
beta_only_data = df[df["beta"] == 60]  # Adjust the filter as needed

# Plot the graph
plt.figure(figsize=(8, 6))
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Te1[K]",
    marker="o",
    label="Te1[K]",
    linewidth=1.5,
    color='blue'
)
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Te2[K]",
    marker="o",
    label="Te2[K]",
    linewidth=1.5,
    color='red'
)
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Tc1[K]",
    marker="o",
    label="Tc1[K]",
    linewidth=1.5,
    color='green'
)
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Tc2[K]",
    marker="o",
    label="Tc2[K]",
    linewidth=1.5,
    color='orange'
)

# Enhance the graph for publication
plt.title("Temperature vs Heat Input at Alpha 90° and Beta 60°", fontsize=14)
plt.xlabel("Heat Input Q [W]", fontsize=12)
plt.ylabel("Temperature [K]", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)  # Use `alpha` for transparency
plt.legend(fontsize=10, title="Temperature Metrics")
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Filter the data for beta only (example: beta == 90)
beta_only_data = df[df["beta"] == 30]  # Adjust the filter as needed

# Plot the graph
plt.figure(figsize=(8, 6))
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Te1[K]",
    marker="o",
    label="Te1[K]",
    linewidth=1.5,
    color='blue'
)
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Te2[K]",
    marker="o",
    label="Te2[K]",
    linewidth=1.5,
    color='red'
)
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Tc1[K]",
    marker="o",
    label="Tc1[K]",
    linewidth=1.5,
    color='green'
)
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Tc2[K]",
    marker="o",
    label="Tc2[K]",
    linewidth=1.5,
    color='orange'
)

# Enhance the graph for publication
plt.title("Temperature vs Heat Input at Alpha 90° and Beta 30°", fontsize=14)
plt.xlabel("Heat Input Q [W]", fontsize=12)
plt.ylabel("Temperature [K]", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)  # Use `alpha` for transparency
plt.legend(fontsize=10, title="Temperature Metrics")
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Filter the data for beta only (example: beta == 90)
beta_only_data = df[df["beta"] == 0]  # Adjust the filter as needed

# Plot the graph
plt.figure(figsize=(8, 6))
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Te1[K]",
    marker="o",
    label="Te1[K]",
    linewidth=1.5,
    color='blue',
    ci=None  # Remove standard deviation shadow
)
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Te2[K]",
    marker="o",
    label="Te2[K]",
    linewidth=1.5,
    color='red',
    ci=None  # Remove standard deviation shadow
)
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Tc1[K]",
    marker="o",
    label="Tc1[K]",
    linewidth=1.5,
    color='green',
    ci=None  # Remove standard deviation shadow
)
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Tc2[K]",
    marker="o",
    label="Tc2[K]",
    linewidth=1.5,
    color='orange',
    ci=None  # Remove standard deviation shadow
)

# Enhance the graph for publication
plt.title("Temperature vs Heat Input at Alpha 90° and Beta 0°", fontsize=14)
plt.xlabel("Heat Input Q [W]", fontsize=12)
plt.ylabel("Temperature [K]", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)  # Use `alpha` for transparency
plt.legend(fontsize=10, title="Temperature Metrics")
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_1000\3803568059.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_1000\3803568059.py:16: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_1000\3803568059.py:26: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_1000\3803568059.py:36: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(

# %% [markdown]
# # For Alpha - Analysis using Change in TR [%]

# %% [markdown]
# ## Change in TR vs Alpha

# %%
# Load the Excel file
file_path = '../../data/observation_alpha_beta.xlsx'
excel_data = pd.ExcelFile(file_path)

# Load the data from the "demo" sheet
df_ = excel_data.parse("demo")

df_.fillna(0,inplace=True)

df_alpha = df_[df_["beta"]==0]

# Drop rows with missing or NaN values in the relevant columns
df_cleaned = df.dropna(subset=["alpha", "Change_in_TR1[%]", "Q[W]"])

# Check unique Q[W] values
unique_Q_values = df_cleaned["Q[W]"].unique()

# Set style and context for publication-quality visuals
sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

# Define a color palette with the number of unique Q[W] values
palette = sns.color_palette("tab10", n_colors=len(unique_Q_values))

# Create the plot
plt.figure(figsize=(8, 6))

sns.lineplot(
    data=df_alpha,
    x="alpha",
    y="Change_in_TR1[%]",
    hue="Q[W]",
    style="Q[W]",  # Different line styles based on "Q[W]"
    markers=True,  # Add markers for data points
    dashes=False,  # Use solid lines
    palette=palette,  # Use the vivid color palette
    marker='o',  # Circular markers
    markerfacecolor='auto',  # Markers filled with line color
    markeredgecolor='black',  # Black edge for better contrast
    markeredgewidth=1  # Adjust the edge width
)

# Add title and labels
plt.title("Change in Thermal Resistance1 (TR1) [%] vs Alpha [°]", fontsize=14, fontweight='bold')
plt.xlabel("Alpha [°]", fontsize=12)
plt.ylabel("Change in Thermal Resistance1 (TR1) [%]", fontsize=12)

# Customize y-axis ticks to include values from (-25) to (40) at every 5
plt.yticks(np.arange(-20, 20, 5))

# Customize legend
plt.legend(
    title="Heat Input [Q(W)]",
    fontsize=10,
    title_fontsize=12,
    loc="lower right",  # Place the legend at the upper-left corner
    frameon=True,  # Add a box around the legend
    shadow=False   # Avoid shadow for a cleaner look
)

# Add grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.6, alpha=0.8)

# Display the plot
#plt.tight_layout()
plt.show()

# %%
display(df)
# Out:
#     Q[W]  alpha  beta  Te1[K]  Te2[K]  dTe[K]  Tc1[K]  Tc2[K]  dTc[K]  \
# 0     40     90     0     348   352.0     4.0   306.0   315.0     9.0
# 1     40     60     0     349   357.0     8.0   304.0   305.0     1.0
# 2     40     30     0     349   358.5     9.5   304.0   306.0     2.0
# 3     60     60     0     350   355.0     5.0   303.0   319.0    16.0
# 4     60     30     0     350   359.0     9.0   305.0   321.0    16.0
# 5     80     90     0     350   355.0     5.0   302.0   320.0    18.0
# 6     80     60     0     355   358.0     3.0   305.0   313.0     8.0
# 7     80     30     0     348   358.0    10.0   303.0   322.0    19.0
# 8     80      0     0     360   364.0     4.0   303.0   303.5     0.5
# 9    100     90     0     352   355.0     3.0   305.0   315.0    10.0
# 29  0.325000       0.204082         20.408163  0.233333       0.348837
#
#     Change_in_TR2[%]  P1[bar]  P2[bar]  dG1[KJ/mol]  dGmin[KJ/mol]  \
# 0           0.000000     0.62     0.75         -155           -190
# 1         -40.540541     0.70     0.80         -140           -160
# 2         -41.891892     0.70     0.83         -130           -150
# 3           0.000000     0.65     1.00         -160           -180
# 4           0.000000     0.75     1.00         -120           -150
# 5           0.000000     0.75     1.00         -125           -150
# 6          20.000000     0.80     1.00          -85           -100
# 7         -34.444444     0.65     1.00         -160           -200
# 8          28.888889     0.70     0.75         -150           -160
# 9           0.000000     0.72     1.00         -130           -160
# 10         13.513514     0.75     1.00         -120           -130
# 11       -113.513514     0.45     1.00         -250           -280
# 12          7.657658     0.67     0.69         -270           -370
# 13          0.000000     0.77     1.00         -100           -130
# 14         18.604651     0.80     1.00          -75            -85
# 15       -245.348837     0.60     1.00         -185           -230
# 16        -33.783784     0.50     0.58         -220           -235
# 17        -21.621622     0.60     0.72         -175           -190
# 18        -29.729730     0.55     0.60         -230           -240
# 19          0.000000     0.62     0.80         -155           -175
# 20          0.000000     0.50     0.74         -220           -225
# 21          0.000000     0.68     0.78         -130           -260
# 22         31.111111     0.62     1.00         -160           -230
# 23         37.777778     0.46     0.92         -255           -300
# 24        -78.378378     0.55     1.00         -150           -170
# 25         27.027027     0.48     1.00         -220           -250
# 26         29.729730     0.60     1.00         -150           -210
# 27        -30.232558     0.60     1.00          215           -230
# 28         41.860465     0.54     1.00         -215           -230
# 29         34.883721     0.52     1.00         -200           -250
#
#     dG2[KJ/mol]
# 0       -100.00
# 1         -0.85
# 2        -90.00
# 3          0.00
# 4          0.00
# 5          0.00
# 6          0.00
# 7          0.00
# 8       -140.00
# 9          0.00
# 10         0.00
# 11         0.00
# 12      -240.00
# 13         0.00
# 14         0.00
# 15         0.00
# 16      -225.00
# 17      -120.00
# 18      -220.00
# 19       -90.00
# 20       -75.00
# 21       -70.00
# 22         0.00
# 23       -20.00
# 24         0.00
# 25         0.00
# 26         0.00
# 27         0.00
# 28         0.00
# 29         0.00

# %%
# Load the Excel file
file_path = '../../data/observation_alpha_beta.xlsx'
excel_data = pd.ExcelFile(file_path)

# Load the data from the "demo" sheet
df_ = excel_data.parse("demo")

df_.fillna(0,inplace=True)

df_alpha = df_[df_["beta"]==0]

# Drop rows with missing or NaN values in the relevant columns
df_cleaned = df.dropna(subset=["alpha", "Change_in_TR2[%]", "Q[W]"])

# Check unique Q[W] values
unique_Q_values = df_cleaned["Q[W]"].unique()

# Set style and context for publication-quality visuals
sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

# Define a color palette with the number of unique Q[W] values
palette = sns.color_palette("tab10", n_colors=len(unique_Q_values))

# Create the plot
plt.figure(figsize=(8, 6))

sns.lineplot(
    data=df_alpha,
    x="alpha",
    y="Change_in_TR2[%]",
    hue="Q[W]",
    style="Q[W]",  # Different line styles based on "Q[W]"
    markers=True,  # Add markers for data points
    dashes=False,  # Use solid lines
    palette=palette,  # Use the vivid color palette
    marker='o',  # Circular markers
    markerfacecolor='auto',  # Markers filled with line color
    markeredgecolor='black',  # Black edge for better contrast
    markeredgewidth=1  # Adjust the edge width
)

# Add title and labels
plt.title("Change in Thermal Resistance2 (TR2) [%] vs Alpha [°]", fontsize=14, fontweight='bold')
plt.xlabel("Alpha [°]", fontsize=12)
plt.ylabel("Change in Thermal Resistance2 (TR2) [%]", fontsize=12)

# Customize y-axis ticks to include values from (-25) to (40) at every 5
plt.yticks(np.arange(-250, 200, 50))

# Customize legend
plt.legend(
    title="Heat Input [Q(W)]",
    fontsize=10,
    title_fontsize=12,
    loc="lower right",  # Place the legend at the upper-left corner
    frameon=True,  # Add a box around the legend
    shadow=False   # Avoid shadow for a cleaner look
)

# Add grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.6, alpha=0.8)

# Display the plot
#plt.tight_layout()
plt.show()

# %% [markdown]
# ## Change in TR vs Q at various alpha

# %%
# Load the Excel file
file_path = '../../data/observation_alpha_beta.xlsx'
excel_data = pd.ExcelFile(file_path)

# Load the data from the "demo" sheet
df_ = excel_data.parse("demo")

df_.fillna(0,inplace=True)

df_alpha = df_[df_["beta"]==0]

# Drop rows with missing or NaN values in the relevant columns
df_cleaned = df.dropna(subset=["alpha", "Change_in_TR1[%]", "Q[W]"])

# Check unique alpha values for the plot
unique_alpha_values = df_cleaned["alpha"].unique()

# Set style and context for publication-quality visuals
sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

# Define a color palette with the number of unique alpha values
palette = sns.color_palette("tab10", n_colors=len(unique_alpha_values))

# Create the plot for Change_in_TR1[%] vs Q[W] at various alpha values
plt.figure(figsize=(8, 6))

sns.lineplot(
    data=df_alpha,
    x="Q[W]",
    y="Change_in_TR1[%]",
    hue="alpha",
    style="alpha",  # Different line styles based on "alpha"
    markers=True,  # Add markers for data points
    dashes=False,  # Use solid lines
    palette=palette,  # Use the vivid color palette
    marker='o',  # Circular markers
    markerfacecolor='auto',  # Markers filled with line color
    markeredgecolor='black',  # Black edge for better contrast
    markeredgewidth=1,  # Adjust the edge width
    ci=None  # Remove standard deviation shadow
)


# Add title and labels
plt.title("Change in Thermal Resistance1 (TR1) [%] vs Heat Input (Q) [W]", fontsize=14, fontweight='bold')
plt.xlabel("Heat Input [Q(W)]", fontsize=12)
plt.ylabel("Change in Thermal Resistance1 (TR1) [%]", fontsize=12)

# Customize y-axis ticks to include values from (-25) to (40) at every 5
plt.yticks(np.arange(-25, 25, 5))

# Customize legend
plt.legend(
    title="Alpha [°]",
    fontsize=10,
    title_fontsize=12,
    loc="upper right",  # Place the legend at the upper-left corner
    frameon=True,  # Add a box around the legend
    shadow=False   # Avoid shadow for a cleaner look
)

# Add grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.6, alpha=0.8)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_1000\1938080061.py:28: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(

# %%
# Load the Excel file
file_path = '../../data/observation_alpha_beta.xlsx'
excel_data = pd.ExcelFile(file_path)

# Load the data from the "demo" sheet
df_ = excel_data.parse("demo")

df_.fillna(0,inplace=True)

df_alpha = df_[df_["beta"]==0]

# Drop rows with missing or NaN values in the relevant columns
df_cleaned = df.dropna(subset=["alpha", "Change_in_TR2[%]", "Q[W]"])

# Check unique alpha values for the plot
unique_alpha_values = df_cleaned["alpha"].unique()

# Set style and context for publication-quality visuals
sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

# Define a color palette with the number of unique alpha values
palette = sns.color_palette("tab10", n_colors=len(unique_alpha_values))

# Create the plot for Change_in_TR2[%] vs Q[W] at various alpha values
plt.figure(figsize=(8, 6))

sns.lineplot(
    data=df_alpha,
    x="Q[W]",
    y="Change_in_TR2[%]",
    hue="alpha",
    style="alpha",  # Different line styles based on "alpha"
    markers=True,  # Add markers for data points
    dashes=False,  # Use solid lines
    palette=palette,  # Use the vivid color palette
    marker='o',  # Circular markers
    markerfacecolor='auto',  # Markers filled with line color
    markeredgecolor='black',  # Black edge for better contrast
    markeredgewidth=1,  # Adjust the edge width
    ci=None  # Remove standard deviation shadow
)

# Add title and labels
plt.title("Change in Thermal Resistance2 (TR2) [%] vs Heat Input (Q) [W]", fontsize=14, fontweight='bold')
plt.xlabel("Heat Input [Q(W)]", fontsize=12)
plt.ylabel("Change in Thermal Resistance2 (TR2) [%]", fontsize=12)

# Customize y-axis ticks to include values from (-25) to (40) at every 5
plt.yticks(np.arange(-250, 250, 50))

# Customize legend
plt.legend(
    title="Alpha [°]",
    fontsize=10,
    title_fontsize=12,
    loc="upper right",  # Place the legend at the upper-left corner
    frameon=True,  # Add a box around the legend
    shadow=False   # Avoid shadow for a cleaner look
)

# Add grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.6, alpha=0.8)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_1000\2599144994.py:28: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(

# %% [markdown]
# ## Change in TR vs Te at various alpha

# %%
# Load the Excel file
file_path = '../../data/observation_alpha_beta.xlsx'
excel_data = pd.ExcelFile(file_path)

# Load the data from the "demo" sheet
df_ = excel_data.parse("demo")

df_.fillna(0,inplace=True)

df_alpha = df_[df_["beta"]==0]

# Drop rows with missing or NaN values in the relevant columns
df_cleaned = df.dropna(subset=["alpha", "Change_in_TR1[%]", "Te1[K]"])

# Check unique alpha values for the plot
unique_alpha_values = df_cleaned["alpha"].unique()

# Set style and context for publication-quality visuals
sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

# Define a color palette with the number of unique alpha values
palette = sns.color_palette("tab10", n_colors=len(unique_alpha_values))

# Create the plot for Change_in_TR1[%] vs Te1[K] at various alpha values
plt.figure(figsize=(8, 6))

sns.lineplot(
    data=df_alpha,
    x="Te1[K]",
    y="Change_in_TR1[%]",
    hue="alpha",
    style="alpha",  # Different line styles based on "alpha"
    markers=True,  # Add markers for data points
    dashes=False,  # Use solid lines
    palette=palette,  # Use the vivid color palette
    marker='o',  # Circular markers
    markerfacecolor='auto',  # Markers filled with line color
    markeredgecolor='black',  # Black edge for better contrast
    markeredgewidth=1,  # Adjust the edge width
    ci=None  # Remove standard deviation shadow
)

# Add title and labels
plt.title("Change in Thermal Resistance1 (TR1) [%] vs Temperature of Evaporator1 (Te1) [K]", fontsize=14, fontweight='bold')
plt.xlabel("Temperature of Evaporator1 (Te1) [K]", fontsize=12)
plt.ylabel("Change in Thermal Resistance1 (TR1) [%]", fontsize=12)

# Customize x-axis ticks to include values from 340 to 360 with a 5-point gap
plt.xticks(np.arange(345, 365, 5))
# Customize y-axis ticks to include values from (-25) to (40) at every 5
plt.yticks(np.arange(-20, 25, 5))

# Customize legend
plt.legend(
    title="Alpha [°]",
    fontsize=10,
    title_fontsize=12,
    loc="upper right",  # Place the legend at the upper-left corner
    frameon=True,  # Add a box around the legend
    shadow=False   # Avoid shadow for a cleaner look
)

# Add grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.6, alpha=0.8)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_1000\759377720.py:28: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(

# %%
# Load the Excel file
file_path = '../../data/observation_alpha_beta.xlsx'
excel_data = pd.ExcelFile(file_path)

# Load the data from the "demo" sheet
df_ = excel_data.parse("demo")

df_.fillna(0,inplace=True)

df_alpha = df_[df_["beta"]==0]

# Drop rows with missing or NaN values in the relevant columns
df_cleaned = df.dropna(subset=["alpha", "Change_in_TR2[%]", "Te2[K]"])

# Check unique alpha values for the plot
unique_alpha_values = df_cleaned["alpha"].unique()

# Set style and context for publication-quality visuals
sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

# Define a color palette with the number of unique alpha values
palette = sns.color_palette("tab10", n_colors=len(unique_alpha_values))

# Create the plot for Change_in_TR2[%] vs Te2[K] at various alpha values
plt.figure(figsize=(8, 6))

sns.lineplot(
    data=df_alpha,
    x="Te2[K]",
    y="Change_in_TR2[%]",
    hue="alpha",
    style="alpha",  # Different line styles based on "alpha"
    markers=True,  # Add markers for data points
    dashes=False,  # Use solid lines
    palette=palette,  # Use the vivid color palette
    marker='o',  # Circular markers
    markerfacecolor='auto',  # Markers filled with line color
    markeredgecolor='black',  # Black edge for better contrast
    markeredgewidth=1,  # Adjust the edge width
    ci=None  # Remove standard deviation shadow
)

# Add title and labels
plt.title("Change in Thermal Resistance2 (TR2) [%] vs Temperature of Evaporator2 (Te2) [K]", fontsize=14, fontweight='bold')
plt.xlabel("Temperature of Evaporator2 (Te2) [K]", fontsize=12)
plt.ylabel("Change in Thermal Resistance2 (TR2) [%]", fontsize=12)

# Customize y-axis ticks to include values from (-25) to (40) at every 5
plt.yticks(np.arange(-140, 100, 20))

# Customize legend
plt.legend(
    title="Alpha [°]",
    fontsize=10,
    title_fontsize=12,
    loc="upper right",  # Place the legend at the upper-left corner
    frameon=True,  # Add a box around the legend
    shadow=False   # Avoid shadow for a cleaner look
)

# Add grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.6, alpha=0.8)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_1000\1109792779.py:28: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(

# %% [markdown]
# # For Beta - Analysis using Change in TR [%]

# %% [markdown]
# ## Change in TR vs Beta

# %%
# Load the Excel file
file_path = '../../data/observation_alpha_beta.xlsx'
excel_data = pd.ExcelFile(file_path)

# Load the data from the "demo" sheet
df_ = excel_data.parse("demo")

df_.fillna(0,inplace=True)

df_beta = df_[df_["alpha"]==90]

# Drop rows with missing or NaN values in the relevant columns
df_cleaned = df.dropna(subset=["beta", "Change_in_TR1[%]", "Q[W]"])

# Check unique Q[W] values
unique_Q_values = df_cleaned["Q[W]"].unique()

# Set style and context for publication-quality visuals
sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

# Define a color palette with the number of unique Q[W] values
palette = sns.color_palette("tab10", n_colors=len(unique_Q_values))

# Create the plot
plt.figure(figsize=(8, 6))

sns.lineplot(
    data=df_beta,
    x="beta",
    y="Change_in_TR1[%]",
    hue="Q[W]",
    style="Q[W]",  # Different line styles based on "Q[W]"
    markers=True,  # Add markers for data points
    dashes=False,  # Use solid lines
    palette=palette,  # Use the vivid color palette
    marker='o',  # Circular markers
    markerfacecolor='auto',  # Markers filled with line color
    markeredgecolor='black',  # Black edge for better contrast
    markeredgewidth=1  # Adjust the edge width
)

# Add title and labels
plt.title("Change in Thermal Resistance1 (TR1) [%] vs Beta [°]", fontsize=14, fontweight='bold')
plt.xlabel("Beta [°]", fontsize=12)
plt.ylabel("Change in Thermal Resistance1 (TR1) [%]", fontsize=12)

# Customize y-axis ticks to include values from (-25) to (40) at every 5
plt.yticks(np.arange(-15, 30, 5))

# Customize legend
plt.legend(
    title="Heat Input [Q(W)]",
    fontsize=10,
    title_fontsize=12,
    loc="upper right",  # Place the legend at the lower-right corner
    frameon=True,  # Add a box around the legend
    shadow=False   # Avoid shadow for a cleaner look
)

# Add grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.6, alpha=0.8)  # Use alpha instead of beta

# Display the plot
#plt.tight_layout()
plt.show()

# %%
# Load the Excel file
file_path = '../../data/observation_alpha_beta.xlsx'
excel_data = pd.ExcelFile(file_path)

# Load the data from the "demo" sheet
df_ = excel_data.parse("demo")

df_.fillna(0,inplace=True)

df_beta = df_[df_["alpha"]==90]

# Drop rows with missing or NaN values in the relevant columns
df_cleaned = df.dropna(subset=["beta", "Change_in_TR2[%]", "Q[W]"])

# Check unique Q[W] values
unique_Q_values = df_cleaned["Q[W]"].unique()

# Set style and context for publication-quality visuals
sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

# Define a color palette with the number of unique Q[W] values
palette = sns.color_palette("tab10", n_colors=len(unique_Q_values))

# Create the plot
plt.figure(figsize=(8, 6))

sns.lineplot(
    data=df_beta,
    x="beta",
    y="Change_in_TR2[%]",
    hue="Q[W]",
    style="Q[W]",  # Different line styles based on "Q[W]"
    markers=True,  # Add markers for data points
    dashes=False,  # Use solid lines
    palette=palette,  # Use the vivid color palette
    marker='o',  # Circular markers
    markerfacecolor='auto',  # Markers filled with line color
    markeredgecolor='black',  # Black edge for better contrast
    markeredgewidth=1  # Adjust the edge width
)

# Add title and labels
plt.title("Change in Thermal Resistance2 (TR2) [%] vs Beta [°]", fontsize=14, fontweight='bold')
plt.xlabel("Beta [°]", fontsize=12)
plt.ylabel("Change in Thermal Resistance2 (TR2) [%]", fontsize=12)

# Customize y-axis ticks to include values from (-25) to (40) at every 5
plt.yticks(np.arange(-150, 200, 50))

# Customize legend
plt.legend(
    title="Heat Input [Q(W)]",
    fontsize=10,
    title_fontsize=12,
    loc="upper right",  # Place the legend at the lower-right corner
    frameon=True,  # Add a box around the legend
    shadow=False   # Avoid shadow for a cleaner look
)

# Add grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.6, alpha=0.8)  # Use alpha instead of beta

# Display the plot
#plt.tight_layout()
plt.show()

# %% [markdown]
# ## Change in TR vs Q at various beta

# %%
# Load the Excel file
file_path = '../../data/observation_alpha_beta.xlsx'
excel_data = pd.ExcelFile(file_path)

# Load the data from the "demo" sheet
df_ = excel_data.parse("demo")

df_.fillna(0,inplace=True)

df_beta = df_[df_["alpha"]==90]

# Drop rows with missing or NaN values in the relevant columns
df_cleaned = df.dropna(subset=["beta", "Change_in_TR1[%]", "Q[W]"])

# Check unique beta values for the plot
unique_beta_values = df_cleaned["beta"].unique()

# Set style and context for publication-quality visuals
sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

# Define a color palette with the number of unique beta values
palette = sns.color_palette("tab10", n_colors=len(unique_beta_values))

# Create the plot for Change_in_TR1[%] vs Q[W] at various beta values
plt.figure(figsize=(8, 6))

sns.lineplot(
    data=df_beta,
    x="Q[W]",
    y="Change_in_TR1[%]",
    hue="beta",
    style="beta",  # Different line styles based on "beta"
    markers=True,  # Add markers for data points
    dashes=False,  # Use solid lines
    palette=palette,  # Use the vivid color palette
    marker='o',  # Circular markers
    markerfacecolor='auto',  # Markers filled with line color
    markeredgecolor='black',  # Black edge for better contrast
    markeredgewidth=1,  # Adjust the edge width
    ci=None  # Remove standard deviation shadow
)

# Add title and labels
plt.title("Change in Thermal Resistance1 (TR1) [%] vs Heat Input (Q) [W]", fontsize=14, fontweight='bold')
plt.xlabel("Heat Input [Q(W)]", fontsize=12)
plt.ylabel("Change in Thermal Resistance1 (TR1) [%]", fontsize=12)

# Customize y-axis ticks to include values from (-25) to (40) at every 5
plt.yticks(np.arange(-15, 30, 5))

# Customize legend
plt.legend(
    title="Beta [°]",
    fontsize=10,
    title_fontsize=12,
    loc="upper left",  # Place the legend at the upper-left corner
    frameon=True,  # Add a box around the legend
    shadow=False   # Avoid shadow for a cleaner look
)

# Add grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.6, alpha=0.8)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_1000\786005046.py:28: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(

# %%
# Load the Excel file
file_path = '../../data/observation_alpha_beta.xlsx'
excel_data = pd.ExcelFile(file_path)

# Load the data from the "demo" sheet
df_ = excel_data.parse("demo")

df_.fillna(0,inplace=True)

df_beta = df_[df_["alpha"]==90]

# Drop rows with missing or NaN values in the relevant columns
df_cleaned = df.dropna(subset=["beta", "Change_in_TR2[%]", "Q[W]"])

# Check unique alpha values for the plot
unique_beta_values = df_cleaned["beta"].unique()

# Set style and context for publication-quality visuals
sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

# Define a color palette with the number of unique alpha values
palette = sns.color_palette("tab10", n_colors=len(unique_beta_values))

# Create the plot for Change_in_TR2[%] vs Q[W] at various beta values
plt.figure(figsize=(8, 6))

sns.lineplot(
    data=df_beta,
    x="Q[W]",
    y="Change_in_TR2[%]",
    hue="beta",
    style="beta",  # Different line styles based on "beta"
    markers=True,  # Add markers for data points
    dashes=False,  # Use solid lines
    palette=palette,  # Use the vivid color palette
    marker='o',  # Circular markers
    markerfacecolor='auto',  # Markers filled with line color
    markeredgecolor='black',  # Black edge for better contrast
    markeredgewidth=1,  # Adjust the edge width
    ci=None  # Remove standard deviation shadow
)

# Add title and labels
plt.title("Change in Thermal Resistance2 (TR2) [%] vs Heat Input (Q) [W]", fontsize=14, fontweight='bold')
plt.xlabel("Heat Input [Q(W)]", fontsize=12)
plt.ylabel("Change in Thermal Resistance2 (TR2) [%]", fontsize=12)

# Customize y-axis ticks to include values from (-25) to (40) at every 5
plt.yticks(np.arange(-80, 100, 20))

# Customize legend
plt.legend(
    title="Beta [°]",
    fontsize=10,
    title_fontsize=12,
    loc="upper left",  # Place the legend at the upper-left corner
    frameon=True,  # Add a box around the legend
    shadow=False   # Avoid shadow for a cleaner look
)

# Add grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.6, alpha=0.8)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_1000\1529982938.py:28: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(

# %% [markdown]
# ## Change in TR vs Te at various beta

# %%
# Load the Excel file
file_path = '../../data/observation_alpha_beta.xlsx'
excel_data = pd.ExcelFile(file_path)

# Load the data from the "demo" sheet
df_ = excel_data.parse("demo")

df_.fillna(0,inplace=True)

df_beta = df_[df_["alpha"]==90]

# Drop rows with missing or NaN values in the relevant columns
df_cleaned = df.dropna(subset=["beta", "Change_in_TR1[%]", "Te1[K]"])

# Check unique beta values for the plot
unique_beta_values = df_cleaned["beta"].unique()

# Set style and context for publication-quality visuals
sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

# Define a color palette with the number of unique beta values
palette = sns.color_palette("tab10", n_colors=len(unique_beta_values))

# Create the plot for Change_in_TR1[%] vs Te1[K] at various beta values
plt.figure(figsize=(8, 6))

sns.lineplot(
    data=df_beta,
    x="Te1[K]",
    y="Change_in_TR1[%]",
    hue="beta",
    style="beta",  # Different line styles based on "beta"
    markers=True,  # Add markers for data points
    dashes=False,  # Use solid lines
    palette=palette,  # Use the vivid color palette
    marker='o',  # Circular markers
    markerfacecolor='auto',  # Markers filled with line color
    markeredgecolor='black',  # Black edge for better contrast
    markeredgewidth=1,  # Adjust the edge width
    ci=None  # Remove standard deviation shadow
)

# Add title and labels
plt.title("Change in Thermal Resistance1 (TR1) [%] vs Temperature of Evaporator1 (Te1) [K]", fontsize=14, fontweight='bold')
plt.xlabel("Temperature of Evaporator1 (Te1) [K]", fontsize=12)
plt.ylabel("Change in Thermal Resistance1 (TR1) [%]", fontsize=12)

# Customize x-axis ticks to include values from 340 to 360 with a 5-point gap
plt.xticks(np.arange(340, 365, 5))

# Customize y-axis ticks to include values from (-25) to (40) at every 5
plt.yticks(np.arange(-15, 30, 5))

# Customize legend
plt.legend(
    title="Beta [°]",
    fontsize=10,
    title_fontsize=12,
    loc="upper right",  # Place the legend at the upper-left corner
    frameon=True,  # Add a box around the legend
    shadow=False   # Avoid shadow for a cleaner look
)

# Add grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.6, alpha=0.8)

# Display the plot
#plt.tight_layout()
plt.show()
# Out:
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_1000\1676701731.py:28: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(

# %%
# Load the Excel file
file_path = '../../data/observation_alpha_beta.xlsx'
excel_data = pd.ExcelFile(file_path)

# Load the data from the "demo" sheet
df_ = excel_data.parse("demo")

df_.fillna(0,inplace=True)

df_beta = df_[df_["alpha"]==90]

# Drop rows with missing or NaN values in the relevant columns
df_cleaned = df.dropna(subset=["beta", "Change_in_TR2[%]", "Te1[K]"])

# Check unique beta values for the plot
unique_beta_values = df_cleaned["beta"].unique()

# Set style and context for publication-quality visuals
sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

# Define a color palette with the number of unique beta values
palette = sns.color_palette("tab10", n_colors=len(unique_beta_values))

# Create the plot for Change_in_TR2[%] vs Te1[K] at various beta values
plt.figure(figsize=(8, 6))

sns.lineplot(
    data=df_beta,
    x="Te2[K]",
    y="Change_in_TR2[%]",
    hue="beta",
    style="beta",  # Different line styles based on "beta"
    markers=True,  # Add markers for data points
    dashes=False,  # Use solid lines
    palette=palette,  # Use the vivid color palette
    marker='o',  # Circular markers
    markerfacecolor='auto',  # Markers filled with line color
    markeredgecolor='black',  # Black edge for better contrast
    markeredgewidth=1,  # Adjust the edge width
    ci=None  # Remove standard deviation shadow
)

# Add title and labels
plt.title("Change in Thermal Resistance2 (TR2) [%] vs Temperature of Evaporator2 (Te2) [K]", fontsize=14, fontweight='bold')
plt.xlabel("Temperature of Evaporator2 (Te2) [K]", fontsize=12)
plt.ylabel("Change in Thermal Resistance2 (TR2) [%]", fontsize=12)

# Customize x-axis ticks to include values from 340 to 360 with a 5-point gap
plt.xticks(np.arange(340, 390, 10))

# Customize y-axis ticks to include values from (-25) to (40) at every 5
#plt.yticks(np.arange(-80, 65, 20))

# Customize legend
plt.legend(
    title="Beta [°]",
    fontsize=10,
    title_fontsize=12,
    loc="upper right",  # Place the legend at the upper-left corner
    frameon=True,  # Add a box around the legend
    shadow=False   # Avoid shadow for a cleaner look
)

# Add grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.6, alpha=0.8)

# Display the plot
#plt.tight_layout()
plt.show()
# Out:
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_1000\1102187531.py:28: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(
