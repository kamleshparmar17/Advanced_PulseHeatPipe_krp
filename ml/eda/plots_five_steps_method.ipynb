# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
df =  pd.read_excel("../../data/observation_alpha_beta.xlsx")

# %%
df.head()
# Out:
#    Q[W]  alpha  beta  Te1[K]  Te2[K]  dTe[K]  Tc1[K]  Tc2[K]  dTc[K]  \
# 0    40     90     0     348   352.0     NaN   306.0   315.0     NaN
# 1    40     60     0     349   357.0     NaN   304.0   305.0     NaN
# 2    40     30     0     349   358.5     NaN   304.0   306.0     NaN
# 3    60     60     0     350   355.0     NaN   303.0   319.0     NaN
# 4    60     30     0     350   359.0     NaN   305.0   321.0     NaN
#
#    TR1[K/W]  Change_in_TR1[%]  TR2[K/W]  Change_in_TR2 [%]  P1[bar]  P2[bar]  \
# 0       NaN               0.0       NaN                0.0     0.62     0.75
# 1       NaN               NaN       NaN                NaN     0.70     0.80
# 2       NaN               NaN       NaN                NaN     0.70     0.83
# 3       NaN               NaN       NaN                NaN     0.65     1.00
# 4       NaN               NaN       NaN                NaN     0.75     1.00
#
#    dG1[KJ/mol]  dGmin[KJ/mol]  dG2[KJ/mol]
# 0         -155           -190      -100.00
# 1         -140           -160        -0.85
# 2         -130           -150       -90.00
# 3         -160           -180         0.00
# 4         -120           -150         0.00

# %% [markdown]
# # Plots for various Alpha and constant Beta (0°)

# %%
# Set style and context for publication-quality visuals
sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

# Define a color palette for clear differentiation
palette = sns.color_palette("tab10")  # Use a vivid palette for clarity

# Create the plot
plt.figure(figsize=(8, 6))

# Plot the data with enhancements
sns.lineplot(
    data=df,
    x="alpha",
    y="TR1[K/W]",
    hue="Q[W]",
    style="Q[W]",  # Different line styles based on "Q[W]"
    markers=True,  # Add markers for data points
    dashes=False,  # Use solid lines
    palette=palette,  # Use the vivid color palette
    marker='o',  # Circular markers
    markerfacecolor='auto',  # Markers filled with line color
    markeredgecolor='black',  # Black edge for better contrast
    markeredgewidth=1  # Adjust the edge width
)

# Add title and labels
plt.title("Thermal Resistance (TR1) vs Alpha", fontsize=14, fontweight='bold')
plt.xlabel("Alpha [°]", fontsize=12)
plt.ylabel("Thermal Resistance (TR1) [K/W]", fontsize=12)

# Customize legend
plt.legend(
    title="Heat Input [Q(W)]",
    fontsize=10,
    title_fontsize=12,
    loc="upper left",  # Place the legend at the upper-right corner
    frameon=True,  # Add a box around the legend
    shadow=False   # Avoid shadow for a cleaner look
)

# Add grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.6, alpha=0.8)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_13584\433388940.py:12: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   sns.lineplot(

# %%
# Set style and context for publication-quality visuals
sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

# Define a color palette for clear differentiation
palette = sns.color_palette("tab10")  # Use a vivid palette for clarity

# Create the plot
plt.figure(figsize=(8, 6))

# Plot the data with enhancements
sns.lineplot(
    data=df,
    x="alpha",
    y="TR2[K/W]",
    hue="Q[W]",
    style="Q[W]",  # Different line styles based on "Q[W]"
    markers=True,  # Add markers for data points
    dashes=False,  # Use solid lines
    palette=palette,  # Use the vivid color palette
    marker='o',  # Circular markers
    markerfacecolor='auto',  # Markers filled with line color
    markeredgecolor='black',  # Black edge for better contrast
    markeredgewidth=1  # Adjust the edge width
)

# Add title and labels
plt.title("Thermal Resistance (TR2) vs Alpha", fontsize=14, fontweight='bold')
plt.xlabel("Alpha [°]", fontsize=12)
plt.ylabel("Thermal Resistance (TR2) [K/W]", fontsize=12)

# Customize legend
plt.legend(
    title="Heat Input [Q(W)]",
    fontsize=10,
    title_fontsize=12,
    loc="upper left",  # Place the legend at the upper-right corner
    frameon=True,  # Add a box around the legend
    shadow=False   # Avoid shadow for a cleaner look
)

# Add grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.6, alpha=0.8)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_13584\2435140647.py:12: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   sns.lineplot(

# %%
# Filter the data for alpha only (example: alpha == 90)
alpha_only_data = df[df["alpha"] == 90]  # Adjust the filter as needed

# Plot the graph
plt.figure(figsize=(8, 6))
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="Te1[K]",
    marker="o",
    label="Te1[K]",
    linewidth=1,
    color='blue'
)
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="Te2[K]",
    marker="o",
    label="Te2[K]",
    linewidth=1,
    color='red'
)
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="Tc1[K]",
    marker="o",
    label="Tc1[K]",
    linewidth=1,
    color='green'
)
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="Tc2[K]",
    marker="o",
    label="Tc2[K]",
    linewidth=1,
    color='orange'
)

# Enhance the graph for publication
plt.title("Temperature vs Heat Input at Alpha 90° and Beta 0°", fontsize=14)
plt.xlabel("Heat Input Q [W]", fontsize=12)
plt.ylabel("Temperature [K]", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=10, title="Temperature Metrics")
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Filter the data for alpha only (example: alpha == 60)
alpha_only_data = df[df["alpha"] == 60]  # Adjust the filter as needed

# Plot the graph
plt.figure(figsize=(8, 6))
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="Te1[K]",
    marker="o",
    label="Te1[K]",
    linewidth=1,
    color='blue'
)
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="Te2[K]",
    marker="o",
    label="Te2[K]",
    linewidth=1,
    color='red'
)
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="Tc1[K]",
    marker="o",
    label="Tc1[K]",
    linewidth=1,
    color='green'
)
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="Tc2[K]",
    marker="o",
    label="Tc2[K]",
    linewidth=1,
    color='orange'
)

# Enhance the graph for publication
plt.title("Temperature vs Heat Input at Alpha 60° and Beta 0°", fontsize=14)
plt.xlabel("Heat Input Q [W]", fontsize=12)
plt.ylabel("Temperature [K]", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=10, title="Temperature Metrics")
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Filter the data for alpha only (example: alpha == 30)
alpha_only_data = df[df["alpha"] == 30]  # Adjust the filter as needed

# Plot the graph
plt.figure(figsize=(8, 6))
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="Te1[K]",
    marker="o",
    label="Te1[K]",
    linewidth=1,
    color='blue'
)
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="Te2[K]",
    marker="o",
    label="Te2[K]",
    linewidth=1,
    color='red'
)
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="Tc1[K]",
    marker="o",
    label="Tc1[K]",
    linewidth=1,
    color='green'
)
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="Tc2[K]",
    marker="o",
    label="Tc2[K]",
    linewidth=1,
    color='orange'
)

# Enhance the graph for publication
plt.title("Temperature vs Heat Input at Alpha 30° and Beta 0°", fontsize=14)
plt.xlabel("Heat Input Q [W]", fontsize=12)
plt.ylabel("Temperature [K]", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=10, title="Temperature Metrics")
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Filter the data for alpha only (example: alpha == 90)
alpha_only_data = df[df["alpha"] == 90]  # Adjust the filter as needed

# Plot the graph
plt.figure(figsize=(8, 6))
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="dTe[K]",
    marker="o",
    label=r"$dT_e[K]$",
    linewidth=2,
    color='blue'
)
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="dTc[K]",
    marker="o",
    label=r"$dT_c[K]$",
    linewidth=2,
    color='red'
)

# Enhance the graph for publication
plt.title(r"Temperature Difference $dT[K]$ vs Heat Input $Q[W]$ at Alpha 90° and Beta 0°", fontsize=14)
plt.xlabel("Heat Input Q [W]", fontsize=12)
plt.ylabel("Temperature Difference dT [K]", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=10, title="Temperature Differences")
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Filter the data for alpha only (example: alpha == 60)
alpha_only_data = df[df["alpha"] == 60]  # Adjust the filter as needed

# Plot the graph
plt.figure(figsize=(8, 6))
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="dTe[K]",
    marker="o",
    label=r"$dT_e[K]$",
    linewidth=2,
    color='blue'
)
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="dTc[K]",
    marker="o",
    label=r"$dT_c[K]$",
    linewidth=2,
    color='red'
)

# Enhance the graph for publication
plt.title(r"Temperature Difference $dT[K]$ vs Heat Input $Q[W]$ at Alpha 60° and Beta 0°", fontsize=14)
plt.xlabel("Heat Input Q [W]", fontsize=12)
plt.ylabel("Temperature Difference dT [K]", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=10, title="Temperature Differences")
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Filter the data for alpha only (example: alpha == 30)
alpha_only_data = df[df["alpha"] == 30]  # Adjust the filter as needed

# Plot the graph
plt.figure(figsize=(8, 6))
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="dTe[K]",
    marker="o",
    label=r"$dT_e[K]$",
    linewidth=2,
    color='blue'
)
sns.lineplot(
    data=alpha_only_data,
    x="Q[W]",
    y="dTc[K]",
    marker="o",
    label=r"$dT_c[K]$",
    linewidth=2,
    color='red'
)

# Enhance the graph for publication
plt.title(r"Temperature Difference $dT[K]$ vs Heat Input $Q[W]$ at Alpha 30° and Beta 0°", fontsize=14)
plt.xlabel("Heat Input Q [W]", fontsize=12)
plt.ylabel("Temperature Difference dT [K]", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=10, title="Temperature Differences")
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # Plots for constant Alpha (90°) and various Beta

# %%
# Set style and context for publication-quality visuals
sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

# Define a color palette for clear differentiation
palette = sns.color_palette("tab10")  # Use a vivid palette for clarity

# Create the plot
plt.figure(figsize=(8, 6))

# Plot the data with enhancements
sns.lineplot(
    data=df,
    x="beta",
    y="TR1[K/W]",
    hue="Q[W]",
    style="Q[W]",  # Different line styles based on "Q[W]"
    markers=True,  # Add markers for data points
    dashes=False,  # Use solid lines
    palette=palette,  # Use the vivid color palette
    marker='o',  # Circular markers
    markerfacecolor='auto',  # Markers filled with line color
    markeredgecolor='black',  # Black edge for better contrast
    markeredgewidth=1  # Adjust the edge width
)

# Add title and labels
plt.title("Thermal Resistance (TR1) vs Beta", fontsize=14, fontweight='bold')
plt.xlabel("Beta [°]", fontsize=12)
plt.ylabel("Thermal Resistance (TR1) [K/W]", fontsize=12)

# Customize legend
plt.legend(
    title="Heat Input [Q(W)]",
    fontsize=10,
    title_fontsize=12,
    loc="upper left",  # Place the legend at the upper-right corner
    frameon=True,  # Add a box around the legend
    shadow=False   # Avoid shadow for a cleaner look
)

# Add grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.6, alpha=0.8)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_8924\1679201442.py:12: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   sns.lineplot(

# %%
# Set style and context for publication-quality visuals
sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

# Define a color palette for clear differentiation
palette = sns.color_palette("tab10")  # Use a vivid palette for clarity

# Create the plot
plt.figure(figsize=(8, 6))

# Plot the data with enhancements
sns.lineplot(
    data=df,
    x="beta",
    y="TR2[K/W]",
    hue="Q[W]",
    style="Q[W]",  # Different line styles based on "Q[W]"
    markers=True,  # Add markers for data points
    dashes=False,  # Use solid lines
    palette=palette,  # Use the vivid color palette
    marker='o',  # Circular markers
    markerfacecolor='auto',  # Markers filled with line color
    markeredgecolor='black',  # Black edge for better contrast
    markeredgewidth=1  # Adjust the edge width
)

# Add title and labels
plt.title("Thermal Resistance (TR2) vs Beta", fontsize=14, fontweight='bold')
plt.xlabel("Beta [°]", fontsize=12)
plt.ylabel("Thermal Resistance (TR2) [K/W]", fontsize=12)

# Customize legend
plt.legend(
    title="Heat Input [Q(W)]",
    fontsize=10,
    title_fontsize=12,
    loc="upper left",  # Place the legend at the upper-right corner
    frameon=True,  # Add a box around the legend
    shadow=False   # Avoid shadow for a cleaner look
)

# Add grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.6, alpha=0.8)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_8924\2247669839.py:12: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   sns.lineplot(

# %%
# Filter the data for beta only (example: beta == 90)
beta_only_data = df[df["beta"] == 90]  # Adjust the filter as needed

# Plot the graph
plt.figure(figsize=(8, 6))
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Te1[K]",
    marker="o",
    label="Te1[K]",
    linewidth=1.5,
    color='blue'
)
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Te2[K]",
    marker="o",
    label="Te2[K]",
    linewidth=1.5,
    color='red'
)
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Tc1[K]",
    marker="o",
    label="Tc1[K]",
    linewidth=1.5,
    color='green'
)
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Tc2[K]",
    marker="o",
    label="Tc2[K]",
    linewidth=1.5,
    color='orange'
)

# Enhance the graph for publication
plt.title("Temperature vs Heat Input at Alpha 90° and Beta 90°", fontsize=14)
plt.xlabel("Heat Input Q [W]", fontsize=12)
plt.ylabel("Temperature [K]", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)  # Use `alpha` for transparency
plt.legend(fontsize=10, title="Temperature Metrics")
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Filter the data for beta only (example: beta == 90)
beta_only_data = df[df["beta"] == 60]  # Adjust the filter as needed

# Plot the graph
plt.figure(figsize=(8, 6))
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Te1[K]",
    marker="o",
    label="Te1[K]",
    linewidth=1.5,
    color='blue'
)
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Te2[K]",
    marker="o",
    label="Te2[K]",
    linewidth=1.5,
    color='red'
)
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Tc1[K]",
    marker="o",
    label="Tc1[K]",
    linewidth=1.5,
    color='green'
)
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Tc2[K]",
    marker="o",
    label="Tc2[K]",
    linewidth=1.5,
    color='orange'
)

# Enhance the graph for publication
plt.title("Temperature vs Heat Input at Alpha 90° and Beta 60°", fontsize=14)
plt.xlabel("Heat Input Q [W]", fontsize=12)
plt.ylabel("Temperature [K]", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)  # Use `alpha` for transparency
plt.legend(fontsize=10, title="Temperature Metrics")
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Filter the data for beta only (example: beta == 90)
beta_only_data = df[df["beta"] == 30]  # Adjust the filter as needed

# Plot the graph
plt.figure(figsize=(8, 6))
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Te1[K]",
    marker="o",
    label="Te1[K]",
    linewidth=1.5,
    color='blue'
)
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Te2[K]",
    marker="o",
    label="Te2[K]",
    linewidth=1.5,
    color='red'
)
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Tc1[K]",
    marker="o",
    label="Tc1[K]",
    linewidth=1.5,
    color='green'
)
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Tc2[K]",
    marker="o",
    label="Tc2[K]",
    linewidth=1.5,
    color='orange'
)

# Enhance the graph for publication
plt.title("Temperature vs Heat Input at Alpha 90° and Beta 30°", fontsize=14)
plt.xlabel("Heat Input Q [W]", fontsize=12)
plt.ylabel("Temperature [K]", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)  # Use `alpha` for transparency
plt.legend(fontsize=10, title="Temperature Metrics")
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Filter the data for beta only (example: beta == 90)
beta_only_data = df[df["beta"] == 0]  # Adjust the filter as needed

# Plot the graph
plt.figure(figsize=(8, 6))
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Te1[K]",
    marker="o",
    label="Te1[K]",
    linewidth=1.5,
    color='blue'
)
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Te2[K]",
    marker="o",
    label="Te2[K]",
    linewidth=1.5,
    color='red'
)
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Tc1[K]",
    marker="o",
    label="Tc1[K]",
    linewidth=1.5,
    color='green'
)
sns.lineplot(
    data=beta_only_data,
    x="Q[W]",
    y="Tc2[K]",
    marker="o",
    label="Tc2[K]",
    linewidth=1.5,
    color='orange'
)

# Enhance the graph for publication
plt.title("Temperature vs Heat Input at Alpha 90° and Beta 0°", fontsize=14)
plt.xlabel("Heat Input Q [W]", fontsize=12)
plt.ylabel("Temperature [K]", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)  # Use `alpha` for transparency
plt.legend(fontsize=10, title="Temperature Metrics")
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Comparative Analysis using Change in TR [%]

# %%
# Set style and context for publication-quality visuals
sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

# Define a color palette for clear differentiation
palette = sns.color_palette("tab10")  # Use a vivid palette for clarity

# Create the plot
plt.figure(figsize=(8, 6))

# Plot the data with enhancements
sns.lineplot(
    data=df,
    x="alpha",
    y="Change_in_TR1[%]",
    hue="Q[W]",
    style="Q[W]",  # Different line styles based on "Q[W]"
    markers=True,  # Add markers for data points
    dashes=False,  # Use solid lines
    palette=palette,  # Use the vivid color palette
    marker='o',  # Circular markers
    markerfacecolor='auto',  # Markers filled with line color
    markeredgecolor='black',  # Black edge for better contrast
    markeredgewidth=1  # Adjust the edge width
)

# Add title and labels
plt.title("Change in Thermal Resistance (TR1) vs Alpha", fontsize=14, fontweight='bold')
plt.xlabel("Alpha [°]", fontsize=12)
plt.ylabel("Change in Thermal Resistance (TR1) [%]", fontsize=12)

# Customize legend
plt.legend(
    title="Heat Input [Q(W)]",
    fontsize=10,
    title_fontsize=12,
    loc="upper left",  # Place the legend at the upper-right corner
    frameon=True,  # Add a box around the legend
    shadow=False   # Avoid shadow for a cleaner look
)

# Add grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.6, alpha=0.8)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_11064\2689381309.py:12: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   sns.lineplot(

# %%
#import pandas as pd
#import seaborn as sns
#import matplotlib.pyplot as plt

# Load the Excel file
file_path = '../../data/observation_alpha_beta.xlsx'
excel_data = pd.ExcelFile(file_path)

# Load the data from the "demo" sheet
df = excel_data.parse("demo")

# Drop rows with missing or NaN values in the relevant columns
df_cleaned = df.dropna(subset=["alpha", "Change_in_TR1[%]", "Q[W]"])

# Check unique Q[W] values
unique_Q_values = df_cleaned["Q[W]"].unique()

# Set style and context for publication-quality visuals
sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

# Define a color palette with the number of unique Q[W] values
palette = sns.color_palette("tab10", n_colors=len(unique_Q_values))

# Create the plot
plt.figure(figsize=(8, 6))

sns.lineplot(
    data=df_cleaned,
    x="alpha",
    y="Change_in_TR1[%]",
    hue="Q[W]",
    style="Q[W]",  # Different line styles based on "Q[W]"
    markers=True,  # Add markers for data points
    dashes=False,  # Use solid lines
    palette=palette,  # Use the vivid color palette
    marker='o',  # Circular markers
    markerfacecolor='auto',  # Markers filled with line color
    markeredgecolor='black',  # Black edge for better contrast
    markeredgewidth=1  # Adjust the edge width
)

# Add title and labels
plt.title("Change in Thermal Resistance1 (TR1) [%] vs Alpha [°]", fontsize=14, fontweight='bold')
plt.xlabel("Alpha [°]", fontsize=12)
plt.ylabel("Change in Thermal Resistance (TR1) [%]", fontsize=12)

# Customize legend
plt.legend(
    title="Heat Input [Q(W)]",
    fontsize=10,
    title_fontsize=12,
    loc="lower right",  # Place the legend at the upper-left corner
    frameon=True,  # Add a box around the legend
    shadow=False   # Avoid shadow for a cleaner look
)

# Add grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.6, alpha=0.8)

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Load the Excel file
file_path = '../../data/observation_alpha_beta.xlsx'
excel_data = pd.ExcelFile(file_path)

# Load the data from the "demo" sheet
df = excel_data.parse("demo")

# Drop rows with missing or NaN values in the relevant columns
df_cleaned = df.dropna(subset=["alpha", "Change_in_TR2[%]", "Q[W]"])

# Check unique Q[W] values
unique_Q_values = df_cleaned["Q[W]"].unique()

# Set style and context for publication-quality visuals
sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

# Define a color palette with the number of unique Q[W] values
palette = sns.color_palette("tab10", n_colors=len(unique_Q_values))

# Create the plot
plt.figure(figsize=(8, 6))

sns.lineplot(
    data=df_cleaned,
    x="alpha",
    y="Change_in_TR2[%]",
    hue="Q[W]",
    style="Q[W]",  # Different line styles based on "Q[W]"
    markers=True,  # Add markers for data points
    dashes=False,  # Use solid lines
    palette=palette,  # Use the vivid color palette
    marker='o',  # Circular markers
    markerfacecolor='auto',  # Markers filled with line color
    markeredgecolor='black',  # Black edge for better contrast
    markeredgewidth=1  # Adjust the edge width
)

# Add title and labels
plt.title("Change in Thermal Resistance2 (TR2) [%] vs Alpha [°]", fontsize=14, fontweight='bold')
plt.xlabel("Alpha [°]", fontsize=12)
plt.ylabel("Change in Thermal Resistance (TR2) [%]", fontsize=12)

# Customize legend
plt.legend(
    title="Heat Input [Q(W)]",
    fontsize=10,
    title_fontsize=12,
    loc="lower right",  # Place the legend at the upper-left corner
    frameon=True,  # Add a box around the legend
    shadow=False   # Avoid shadow for a cleaner look
)

# Add grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.6, alpha=0.8)

# Display the plot
plt.tight_layout()
plt.show()
