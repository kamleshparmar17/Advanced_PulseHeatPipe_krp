# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
df =  pd.read_excel("../../data/observation_alpha_beta.xlsx")

# %%
df.head()
# Out:
#    Q[W]  alpha  beta  Te1[K]  Te2[K]  dTe[K]  Tc1[K]  Tc2[K]  dTc[K]  \
# 0    40     90     0     348   352.0     4.0   306.0   315.0     9.0
# 1    40     60     0     349   357.0     8.0   304.0   305.0     1.0
# 2    40     30     0     349   358.5     9.5   304.0   306.0     2.0
# 3    60     60     0     350   355.0     5.0   303.0   319.0    16.0
# 4    60     30     0     350   359.0     9.0   305.0   321.0    16.0
#
#    TR1[K/W]  TR2[K/W]  P1[bar]  P2[bar]  dG1[KJ/mol]  dGmin[KJ/mol]  \
# 0  1.050000  0.925000     0.62     0.75         -155           -190
# 1  1.125000  1.300000     0.70     0.80         -140           -160
# 2  1.125000  1.312500     0.70     0.83         -130           -150
# 3  0.783333  0.600000     0.65     1.00         -160           -180
# 4  0.750000  0.633333     0.75     1.00         -120           -150
#
#    dG2[KJ/mol]
# 0      -100.00
# 1        -0.85
# 2       -90.00
# 3         0.00
# 4         0.00

# %%
# Set style and context for publication-quality visuals
sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

# Define a color palette for clear differentiation
palette = sns.color_palette("tab10")  # Use a vivid palette for clarity

# Create the plot
plt.figure(figsize=(10, 7))

# Plot the data with enhancements
sns.lineplot(
    data=df,
    x="alpha",
    y="TR1[K/W]",
    hue="Q[W]",
    style="Q[W]",  # Different line styles based on "Q[W]"
    markers=True,  # Add markers for data points
    dashes=False,  # Use solid lines
    palette=palette,  # Use the vivid color palette
    marker='o',  # Circular markers
    markerfacecolor='auto',  # Markers filled with line color
    markeredgecolor='black',  # Black edge for better contrast
    markeredgewidth=1  # Adjust the edge width
)

# Add title and labels
plt.title("Thermal Resistance1 vs Alpha", fontsize=16, fontweight='bold')
plt.xlabel("Alpha", fontsize=14)
plt.ylabel("Thermal Resistance1 [K/W]", fontsize=14)

# Customize legend
plt.legend(
    title="Heat Input [Q(W)]",
    fontsize=12,
    title_fontsize=14,
    loc="upper right",  # Place the legend at the upper-right corner
    frameon=True,  # Add a box around the legend
    shadow=False   # Avoid shadow for a cleaner look
)

# Add grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.6, alpha=0.8)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_13584\952273581.py:12: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   sns.lineplot(

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set style and context for publication-quality visuals
sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

# Define a color palette for clear differentiation
palette = sns.color_palette("tab10")  # Use a vivid palette for clarity

# Create the plot
plt.figure(figsize=(10, 7))

# Plot the data with enhancements
sns.lineplot(
    data=df,
    x="alpha",
    y="TR2[K/W]",
    hue="Q[W]",
    style="Q[W]",  # Different line styles based on "Q[W]"
    markers=True,  # Add markers for data points
    dashes=False,  # Use solid lines
    palette=palette,  # Use the vivid color palette
    marker='o',  # Circular markers
    markerfacecolor='auto',  # Markers filled with line color
    markeredgecolor='black',  # Black edge for better contrast
    markeredgewidth=1  # Adjust the edge width
)

# Add title and labels
plt.title("Thermal Resistance (TR2) vs Alpha", fontsize=16, fontweight='bold')
plt.xlabel("Alpha", fontsize=14)
plt.ylabel("Thermal Resistance TR2 [K/W]", fontsize=14)

# Customize legend
plt.legend(
    title="Heat Input [Q(W)]",
    fontsize=12,
    title_fontsize=14,
    loc="upper right",  # Place the legend at the upper-right corner
    frameon=True,  # Add a box around the legend
    shadow=False   # Avoid shadow for a cleaner look
)

# Add grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.6, alpha=0.8)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MSI (WIN10)\AppData\Local\Temp\ipykernel_13584\2297778605.py:15: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   sns.lineplot(
