# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
df =  pd.read_excel("../../data/observation_alpha_beta.xlsx")

# %%
df.head()
# Out:
#    Q[W]  alpha  beta  Te1[K]  Te2[K]  dTe[K]  Tc1[K]  Tc2[K]  dTc[K]  \
# 0    40     60     0     349   357.0     8.0     304   305.0     1.0
# 1    40     30     0     349   358.5     9.5     304   306.0     2.0
# 2    60     60     0     350   355.0     5.0     303   319.0    16.0
# 3    60     30     0     350   359.0     9.0     305   321.0    16.0
# 4    80     90     0     350   355.0     5.0     302   320.0    18.0
#
#    TR1[K/W]  TR2[K/W]  P1[bar]  P2[bar]  dG1[KJ/mol]  dGmin[KJ/mol]  \
# 0  1.125000  1.300000     0.70     0.80         -140           -160
# 1  1.125000  1.312500     0.70     0.83         -130           -150
# 2  0.783333  0.600000     0.65     1.00         -160           -180
# 3  0.750000  0.633333     0.75     1.00         -120           -150
# 4  0.600000  0.437500     0.75     1.00         -125           -150
#
#    dG2[KJ/mol] Unnamed: 16
# 0        -0.85         NaN
# 1       -90.00         NaN
# 2         0.00         NaN
# ...

# %%
plt.figure(figsize=(8,6))
sns.lineplot(data=df,x=df["alpha"],y=df["TR1[K/W]"],hue=df["Q[W]"],markers=True, dashes=False)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.lineplot(data=df,x=df["alpha"],y=df["TR2[K/W]"],hue=df["Q[W]"],markers=True, dashes=False)
plt.show()
